# %%
# Import modul lokal
import sys
sys.path.append('../src')

# %%
pip install ccxt
# Out:
# ...
#   Using cached ccxt-4.5.40-py2.py3-none-any.whl.metadata (138 kB)
# ...
#   Using cached aiodns-4.0.0-py3-none-any.whl.metadata (7.7 kB)
# ...
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# ...
# Using cached ccxt-4.5.40-py2.py3-none-any.whl (6.5 MB)
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.3 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 4.0 MB/s  0:00:00
# Using cached aiodns-4.0.0-py3-none-any.whl (11 kB)
# ...
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# ...
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/3.5 MB 3.4 MB/s eta 0:00:01
#    ------------ --------------------------- 1.0/3.5 MB 3.0 MB/s eta 0:00:01
# ...

# %%
from data_loader import fetch_full_history
from features import add_features_v2

# Ambil Data
df_coinbase = fetch_full_history(symbol='BTC/USD', start_date='2015-01-01T00:00:00Z')

# %%
df_coinbase.head()
# Out:
#               open    high     low   close       volume
# timestamp
# 2015-07-20  277.98  280.00  277.37  280.00   782.883420
# 2015-07-21  279.96  281.27  276.85  277.32  4943.559434
# 2015-07-22  277.33  278.54  275.01  277.89  4687.909383
# 2015-07-23  277.96  279.75  276.28  277.39  5306.919575
# 2015-07-24  277.23  291.52  276.43  289.12  7362.469083

# %%
# Proses Fitur
btc_features_v2 = add_features_v2(df_coinbase)
btc_features_v2.head()
# Out:
#               open    high     low   close       volume  log_return  \
# timestamp
# 2015-09-12  240.90  241.12  235.26  236.50  5480.204714   -0.018434
# 2015-09-13  236.50  236.91  229.72  230.82  5004.429976   -0.024310
# 2015-09-14  230.83  233.99  228.01  231.01  7984.562513    0.000823
# 2015-09-15  231.02  232.43  230.26  230.60  7118.307926   -0.001776
# 2015-09-16  230.67  232.00  226.85  229.73  7655.652988   -0.003780
#
#             volatility  trend_slope  volume_zscore  price_dist_ma
# timestamp
# 2015-09-12    0.026113    -0.016007      -0.580751      -0.067141
# 2015-09-13    0.026627    -0.017906      -0.719326      -0.085297
# 2015-09-14    0.018803    -0.019933       0.206290      -0.079959
# 2015-09-15    0.014268    -0.021975       0.260590      -0.076915
# 2015-09-16    0.014026    -0.024469       0.755657      -0.075510

# %%
import os
save_path = os.path.join('..', 'data', 'btc_usd_coinbase.csv')
save_path_features = os.path.join('..', 'data', 'btc_usd_coinbase_features_v2.csv')

df_coinbase.to_csv(save_path)
btc_features_v2.to_csv(save_path_features)
